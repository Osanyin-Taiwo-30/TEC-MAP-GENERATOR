# %%
#snippet to set notebook to screen width
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %load_ext autoreload
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %autoreload 2
# %matplotlib inline
from tec_map_generator import generate_tec_map
import matplotlib.pyplot as plt

# %% [markdown]
# # Chetumal, PLR Take, Feb 3, 2010, HIGH TEC

# %%
# Chetumal (PLR case, High tec, feb 3 2010)
# 18.5002° N, 88.2961 W
# data set: https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP268343240-L1.0.zip
generate_tec_map(2010, 34, 16.3, 18.5, -88.29)
# Out:
# ftp://cddis.gsfc.nasa.gov/gps/products/ionex/2010/034/igsg0340.10i.Z
# RMextract/getIONEX.py:68: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   times=np.zeros(NumberOfMaps,dtype='float32');
# RMextract/getIONEX.py:69: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   tecdata = np.zeros((NumberOfMaps,pointsLat,pointsLon))
# RMextract/getIONEX.py:70: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   rmsdata = np.zeros((NumberOfMaps,pointsLat,pointsLon))
# Run matplotlib.pyplot.show() to see the TEC map!
# TEC Value ~= 23.905
# (23.905000000000005,
#  array([[ 3.86 ,  3.86 ,  3.86 , ...,  3.86 ,  3.86 ,  3.86 ],
#         [ 3.445,  3.46 ,  3.46 , ...,  3.46 ,  3.46 ,  3.445],
#         [ 3.09 ,  3.09 ,  3.09 , ...,  3.19 ,  3.09 ,  3.09 ],
#         ...,
#         [ 7.615,  7.745,  7.76 , ...,  7.685,  7.685,  7.615],
#         [ 8.665,  8.68 ,  8.795, ...,  8.635,  8.665,  8.665],
#         [ 9.49 ,  9.59 ,  9.605, ...,  9.475,  9.475,  9.49 ]]))

# %%
# Chetumal (PLR case, High tec, feb 3 2010)
# 18.5002° N, 88.2961 W
# data set: https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP268343240-L1.0.zip
generate_tec_map(2010, 32, 4.5, 18.5, -88.29)
# Out:
# ftp://cddis.gsfc.nasa.gov/gps/products/ionex/2010/032/igsg0320.10i.Z
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-4-dc49afa9100a> in <module>()
#       2 # 18.5002° N, 88.2961 W
#       3 # data set: https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP268343240-L1.0.zip
# ----> 4 generate_tec_map(2010, 32, 4.5, 18.5, -88.29)
#
# /Users/tbuchy/dev/tec-map-creator/tec_map_generator.py in generate_tec_map(year, day_of_year, hour_in_day, lat_of_interest, lon_of_interest, plot)
#      58     :returns tec_value, tec_map: tuple of the actual TEC at a given lat long, and a numpy array of sampled TEC values.
#      59     """
# ---> 60     path_to_ionex = get_ionex_file(year, day_of_year)
#      61
#      62     tec_struct = ionex.readTEC(path_to_ionex) # some data struct is returned from the library.
#
# /Users/tbuchy/dev/tec-map-creator/tec_map_generator.py in get_ionex_file(year, day_of_year)
#      29     print IONEX_DATASTORE
#      30     req = urllib2.Request(IONEX_DATASTORE)
# ---> 31     resp = urllib2.urlopen(req)
#      32     with open(igsg_file_name_z, 'wb') as fp:
#      33         fp.write(resp.read())
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     429             req = meth(req)
#     430
# --> 431         response = self._open(req, data)
#     432
#     433         # post-process response
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     447         protocol = req.get_type()
#     448         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 449                                   '_open', req)
#     450         if result:
#     451             return result
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     407             func = getattr(handler, meth_name)
#     408
# --> 409             result = func(*args)
#     410             if result is not None:
#     411                 return result
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in ftp_open(self, req)
#    1417                    value in ('a', 'A', 'i', 'I', 'd', 'D'):
#    1418                     type = value.upper()
# -> 1419             fp, retrlen = fw.retrfile(file, type)
#    1420             headers = ""
#    1421             mtype = mimetypes.guess_type(req.get_full_url())[0]
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib.pyc in retrfile(self, file, type)
#     902             try:
#     903                 cmd = 'RETR ' + file
# --> 904                 conn, retrlen = self.ftp.ntransfercmd(cmd)
#     905             except ftplib.error_perm, reason:
#     906                 if str(reason)[:3] != '550':
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/ftplib.pyc in ntransfercmd(self, cmd, rest)
#     333         if self.passiveserver:
#     334             host, port = self.makepasv()
# --> 335             conn = socket.create_connection((host, port), self.timeout)
#     336             try:
#     337                 if rest is not None:
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/socket.pyc in create_connection(address, timeout, source_address)
#     573
#     574     if err is not None:
# --> 575         raise err
#     576     else:
#     577         raise error("getaddrinfo returns an empty list")
#
# URLError: <urlopen error ftp error: [Errno 60] Operation timed out>

# %% [markdown]
# # Chetumal, PLR Take, Feb 6, 2011, HIGH TEC

# %%
# Chetumal (PLR case, High tec, feb 6 2011)
# 18.5002° N, 88.2961 W
# data set: https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP268343240-L1.0.zip
generate_tec_map(2011, 37, 16.3, 18.5, -88.29)

# %% [markdown]
# # Panama Coast, FBS Take, Jan 30, 2008, MEDIUM TEC

# %%
# Panama Coast 2008 01 30 15 26 46 105
# 8.865° N,  -77.57
# data set: ALPSRP107443440
generate_tec_map(2008, 30, 15.5, 8.865, -77.57)

# %% [markdown]
# # Panama Coast, FBS Take, Jan 31, 2008, LOW TEC

# %%
# Panama Coast 2008 01 31 03 51 36 523
# 8.865° N,  -77.57
# data set: ALPSRP107520160
generate_tec_map(2008, 31, 4.0, 8.865, -77.57)

# %% [markdown]
# # Isla Santa Cruz, FBS Take, Jan 31, 2008, MEDIUM TEC

# %%
# ISLAND 2008 01 31 16 10 08 106
# -0.5,  -90.0
# data set: ALPSRP107593630
generate_tec_map(2008, 31, 16.16, -0.5, -90.0)

# %% [markdown]
# # Isla Santa Cruz, FBS Take, Jan 31, 2008, LOW TEC

# %%
# ISLAND 2008 01 30 04 46 57 627
# -0.5,  -90.0
# data set: ALPSRP107377170
generate_tec_map(2008, 30, 4.75, -0.5, -90.0)
