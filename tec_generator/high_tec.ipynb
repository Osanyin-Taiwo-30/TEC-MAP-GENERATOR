# %%
#snippet to set notebook to screen width
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %load_ext autoreload
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %autoreload 2
# %matplotlib inline
from tec_map_generator import generate_tec_map, get_ionex_file, get_tec_for_lat_lon_idx
import matplotlib.pyplot as plt

def find_map_location_and_tec(year, day_in_year, hour_in_day, lat_of_interest, lon_of_interest):
    ionex_file = get_ionex_file(year, day_in_year)
    LAT = lat_of_interest
    LON = lon_of_interest
    tecs = generate_tec_map(ionex_file, hour_in_day=hour_in_day, lat_of_interest=lat_of_interest, lon_of_interest=lon_of_interest)
    lat_idx, lon_idx = get_tec_for_lat_lon_idx(tecs, lat_of_interest, lon_of_interest)
    print "TEC VALUE AT {}, {}: {}".format(lat_of_interest, lon_of_interest, tecs[lat_idx][lon_idx])
    plt.show()

# %% [markdown]
# # Chetumal, PLR Take, Feb 3, 2010, HIGH TEC

# %%
# Chetumal (PLR case, High tec, feb 3 2010)
# 18.5002° N, 88.2961 W
# data set: https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP268343240-L1.0.zip
find_map_location_and_tec(2010, 34, 16.3, 18.5, -88.29)
# Out:
# ftp://cddis.gsfc.nasa.gov/gps/products/ionex/2010/034/igsg0340.10i.Z
# ../RMextract/getIONEX.py:68: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   times=np.zeros(NumberOfMaps,dtype='float32');
# ../RMextract/getIONEX.py:69: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   tecdata = np.zeros((NumberOfMaps,pointsLat,pointsLon))
# ../RMextract/getIONEX.py:70: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   rmsdata = np.zeros((NumberOfMaps,pointsLat,pointsLon))
# TEC VALUE AT 18.5, -88.29: 23.905
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c73df1ca9842> in <module>()
#       2 # 18.5002° N, 88.2961 W
#       3 # data set: https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP268343240-L1.0.zip
# ----> 4 find_map_location_and_tec(2010, 34, 16.3, 18.5, -88.29)
#
# <ipython-input-3-7ed92bae185d> in find_map_location_and_tec(year, day_in_year, hour_in_day, lat_of_interest, lon_of_interest)
#      10     lat_idx, lon_idx = get_tec_for_lat_lon_idx(tecs, lat_of_interest, lon_of_interest)
#      11     print "TEC VALUE AT {}, {}: {}".format(lat_of_interest, lon_of_interest, tecs[lat_idx][lon_idx])
# ---> 12     plt.show()
#
# NameError: global name 'plt' is not defined

# %%
# Chetumal (PLR case, High tec, feb 3 2010)
# 18.5002° N, 88.2961 W
# data set: https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP268343240-L1.0.zip
find_map_location_and_tec(2010, 32, 4.5, 18.5, -88.29)
# Out:
# ftp://cddis.gsfc.nasa.gov/gps/products/ionex/2010/032/igsg0320.10i.Z
# TEC VALUE AT 18.5, -88.29: 9.25

# %% [markdown]
# # Chetumal, PLR Take, Feb 6, 2011, HIGH TEC

# %%
# Chetumal (PLR case, High tec, feb 6 2011)
# 18.5002° N, 88.2961 W
# data set: https://datapool.asf.alaska.edu/L1.0/A3/ALPSRP268343240-L1.0.zip
find_map_location_and_tec(2011, 37, 16.3, 18.5, -88.29)
# Out:
# ftp://cddis.gsfc.nasa.gov/gps/products/ionex/2011/037/igsg0370.11i.Z
# TEC VALUE AT 18.5, -88.29: 27.65

# %% [markdown]
# # Panama Coast, FBS Take, Jan 30, 2008, MEDIUM TEC

# %%
# Panama Coast 2008 01 30 15 26 46 105
# 8.865° N,  -77.57
# data set: ALPSRP107443440
find_map_location_and_tec(2008, 30, 15.5, 8.865, -77.57)
# Out:
# ftp://cddis.gsfc.nasa.gov/gps/products/ionex/2008/030/igsg0300.08i.Z
# TEC VALUE AT 8.865, -77.57: 14.625

# %% [markdown]
# # Panama Coast, FBS Take, Jan 31, 2008, LOW TEC

# %%
# Panama Coast 2008 01 31 03 51 36 523
# 8.865° N,  -77.57
# data set: ALPSRP107520160
find_map_location_and_tec(2008, 31, 4.0, 8.865, -77.57)
# Out:
# ftp://cddis.gsfc.nasa.gov/gps/products/ionex/2008/031/igsg0310.08i.Z
# TEC VALUE AT 8.865, -77.57: 8.3

# %% [markdown]
# # Isla Santa Cruz, FBS Take, Jan 31, 2008, MEDIUM TEC

# %%
# ISLAND 2008 01 31 16 10 08 106
# -0.5,  -90.0
# data set: ALPSRP107593630
find_map_location_and_tec(2008, 31, 16.16, -0.5, -90.0)
# Out:
# ftp://cddis.gsfc.nasa.gov/gps/products/ionex/2008/031/igsg0310.08i.Z
# TEC VALUE AT -0.5, -90.0: 15.468

# %% [markdown]
# # Isla Santa Cruz, FBS Take, Jan 31, 2008, LOW TEC

# %%
# ISLAND 2008 01 30 04 46 57 627
# -0.5,  -90.0
# data set: ALPSRP107377170
find_map_location_and_tec(2008, 30, 4.75, -0.5, -90.0)
# Out:
# ftp://cddis.gsfc.nasa.gov/gps/products/ionex/2008/030/igsg0300.08i.Z
# TEC VALUE AT -0.5, -90.0: 8.45

# %%
# ISLAND 2008 01 30 04 46 57 627
# -0.5,  -90.0
# data set: ALPSRP107377170
find_map_location_and_tec(2011, 51, 14.5, -25.5, -70.57)
# Out:
# ftp://cddis.gsfc.nasa.gov/gps/products/ionex/2011/051/igsg0510.11i.Z
# TEC VALUE AT -25.5, -70.57: 21.425
